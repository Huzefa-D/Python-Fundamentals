# %%
Introduction to python programming :

# %%
Understanding the variable in python :

# %%
a = 5
b = 5
c = a+b
print(c)
# Out:
# 10

# %%
Rules for declaring the variable :

# %%
Rule No 1 : No namespace for declaring the variables.

# %%
first name ="Hujefa"
print(first name)
# Out:
#   Cell In[2], line 1
#     first name ="Hujefa"
#           ^
# SyntaxError: invalid syntax

# %%
first_name ="Hujefa"
print(first_name)
# Out:
# Hujefa

# %%
Rule No 2 : A variable name should not start with a number ** (Important)

# %%
5Name ='HD'
print(5Name)
# Out:
#   Cell In[4], line 1
#     5Name ='HD'
#     ^
# SyntaxError: invalid decimal literal

# %%
Name5 ='HD'
print(Name5)
# Out:
# HD

# %%
Rule No 3 : A variable should not contain any special characters

# %%
Example : (@ # $ % & *)

# %%
name$ ='Hujefa'
print(name$)
# Out:
#   Cell In[7], line 1
#     name$ ='Hujefa'
#         ^
# SyntaxError: invalid syntax

# %%
name ='Hujefa'
print(name)
# Out:
# Hujefa

# %%
Introduction to Datatypes in python :
  1. String ---------> str
  2. Numbers ----------> integers(int) and float( Decinmal Numbers 0.1,0.2,1.1)
  3. lists ------> list
  4. tuples --------> tuple
  5. dictonaries ---------> dict

# %%
Note : python is a case sensitive programming language.

# %%
Classification of Datatypes :
 Brodly Datatypes are classified in two catgories:
        1. Mutable datatypes ----> which we can edit/alter ---> flexible in nature 
        2. Immutable datatypes ---> which we cannot be  able to edit ---> fixed in nature

# %%
Introduction to string datatype :

# %%
Defination : A string is noting but a series of characters declared in quotes.
    classification : It is classified as an immutable dtattype 
    how to define the string ? ---->
          1. single quote
          2. double quote

# %%
name ='Hujefa'
print(name)
# Out:
# Hujefa

# %%
name ="HD"
print(name)
# Out:
# HD
