# %%
# req : i want to know which type of datatype it is?

# %%
name ='Hujefa'
print(name)
# Out:
# Hujefa

# %%
type(name) #str-----------> string datatype
# Out:
# str

# %%
full_name ="hujefa dadhiwale"
print(full_name)
# Out:
# hujefa dadhiwale

# %%
print(full_name.title())
# Out:
# Hujefa Dadhiwale

# %%
# Full name in capital case letter

# %%
print(full_name.upper())
# Out:
# HUJEFA DADHIWALE

# %%
# Full name in small case letter

# %%
print(full_name.lower())
# Out:
# hujefa dadhiwale

# %%
# Adding white space to the strings :

# %%
print('fav_programming_lang:cc++javapython')
# Out:
# fav_programming_lang:cc++javapython

# %%
print('fav_programming_lang:\nc\nc++\njava\npython') #\n -------> new line delimiter
# Out:
# fav_programming_lang:
# c
# c++
# java
# python

# %%
print('fav_programming_lang:\n\tc\n\tc++\n\tjava\n\tpython') #\t -------> new tab delimiter
# Out:
# fav_programming_lang:
# 	c
# 	c++
# 	java
# 	python
